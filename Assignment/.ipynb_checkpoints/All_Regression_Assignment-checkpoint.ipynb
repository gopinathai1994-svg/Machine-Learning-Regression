# %%
import pandas as pd
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first =True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='str')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]
independent
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#  split the train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size = 0.3,random_state=0)

# %%
# multiple linear regression
# from sklearn.linear_model import LinearRegression
# regressor = LinearRegression()
# regressor.fit(x_train,y_train)
# regressor

# %%
# SVM regression
# standarised method
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)
# x_train
# from sklearn.svm import SVR
# regressor = SVR(kernel = 'sigmoid',C=1000)
# regressor.fit(x_train,y_train)

# %%
# Decision Tree regression
# standarised method
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.transform(x_test)
# x_train

# from sklearn.tree import DecisionTreeRegressor
# regressor = DecisionTreeRegressor(criterion='squared_error')
# regressor.fit(x_train,y_train)

# %%
# Random Forest regression
# standarised method
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 50,random_state=42,criterion='poisson')
regressor.fit(x_train,y_train)
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1403: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(criterion='poisson', n_estimators=50, random_state=42)

# %%
# import matplotlib.pyplot as plt
# from sklearn import tree
# tree.plot_tree(regressor)
# plt.show()

# %%
# Y_Predict
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([11408.9157224,  9815.0720248, 44909.4009622, 13073.282168 ,
#         9600.2299082, 12349.8140488,  2178.453263 , 11413.1091814,
#         7033.979202 ,  5211.234069 ,  7990.596602 , 20676.551065 ,
#        10798.9067162,  5501.8503054, 24725.3667884, 13411.8625764,
#        13478.6340388,  4205.0323218,  6546.6249196, 33902.1803426,
#        23788.005128 , 15302.9616768, 10061.4741166, 28047.0268578,
#         4050.673681 ,  5076.9112636,  3967.8096402,  8086.9618006,
#         3697.948274 , 10357.045074 ,  7794.6594916, 48362.422062 ,
#        13989.806553 , 15097.5071104, 16291.7484168,  3838.616792 ,
#         8677.924418 , 37862.5092378, 39643.701531 ,  4134.611431 ,
#         8515.9889858,  3411.33217  , 20148.478302 , 47922.801848 ,
#        38284.1168902,  4788.5925124, 13417.8899434,  6527.302194 ,
#         4904.226677 , 13297.3176692,  3680.554082 ,  4318.1370892,
#        26630.1263684, 48048.453679 , 11809.340687 ,  6892.3946438,
#         3483.2411172, 10429.1003904,  9896.4290094, 14468.4596892,
#         1650.533309 , 46782.323252 , 16765.3752392, 18299.6192598,
#        12300.9502036,  9846.01877  , 33828.1258036, 42095.0392852,
#         3092.680425 , 12895.4225804, 19655.2132164, 13063.6592242,
#        16960.352641 , 13886.632734 , 12842.563588 , 17157.3217878,
#         8646.6179842, 14872.71608  , 19593.66312  , 46891.0474364,
#        11539.230229 , 48445.4943888,  5450.707223 , 10984.5800528,
#        40890.7510872, 19233.755209 ,  3344.3516024,  3709.3407508,
#        13920.4004226, 40281.9159434,  5682.237539 , 14285.7443848,
#         2849.069082 , 10275.2857434,  9112.9347422,  4197.68756  ,
#         5975.608535 ,  4808.0273736, 10035.0611742, 22982.3008572,
#         3596.574701 ,  2061.194051 ,  2524.549481 , 47064.5275914,
#        12755.7832464,  4678.6090728, 16434.4164234, 14774.700594 ,
#        34814.2092296,  6777.390641 ,  5103.731286 ,  8852.256336 ,
#         2920.1518594,  4247.0327454, 20845.385738 , 16608.395342 ,
#        13807.3084812,  2807.144937 ,  3470.8448352, 11346.7996664,
#         9945.7603076, 15216.4418982, 20026.466397 , 10901.9041708,
#        17003.368102 ,  2148.777886 , 12147.7259512,  9360.68456  ,
#        17381.3541184,  2291.433071 ,  7663.1940768, 46608.6687072,
#         3654.3708798,  6968.6792086,  1773.511717 , 14559.3869534,
#         5901.1298946, 11984.610313 , 46298.3830974, 18065.402917 ,
#         8961.915794 , 45719.1184696, 17367.4119016, 10384.2782024,
#         9975.6725032,  4846.944532 , 28703.355397 ,  4855.3383754,
#        14649.4216452,  2276.877984 , 16580.619048 ,  3391.7982602,
#        24575.558372 , 10298.6664464,  7451.3319618, 40827.3200766,
#         5582.6568378,  5266.064339 , 29378.9235894,  2627.4960778,
#        11023.1889644,  3763.0765838, 11219.97088  ,  4139.49817  ,
#         7574.4306114,  6258.311508 , 45065.046983 ,  9229.3536938,
#        44539.0369852, 39388.857886 ,  5832.091825 , 11804.5529198,
#         1724.921189 ,  4456.514294 ,  3302.2562328,  9192.128791 ,
#        45908.2179544, 11379.366406 ,  1867.171278 , 13787.5969176,
#         2133.143396 , 12192.0764298,  7370.731912 ,  2715.516568 ,
#         3277.62026  , 37469.7593636,  6737.903758 ,  1855.9779   ,
#        40582.6403974, 13348.6320688, 43770.1089716, 11655.696432 ,
#         6498.9582992,  3814.3722294,  2189.859017 , 17326.8534948,
#         5006.301248 ,  1922.686376 , 11660.5965718,  7212.81047  ,
#         6011.380947 ,  7972.12883  ,  8332.599313 , 43723.0308922,
#         4404.3639432, 13711.5384514,  7460.974146 , 11296.129236 ,
#        10988.732057 ,  5758.4476646, 17052.832374 , 14782.432547 ,
#        21190.7130798, 19453.7020454])

# %%
# r2score matrics
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 0.8593601155052777

# %%
import pickle
filename = 'random_regression.sav'
pickle.dump(regressor,open(filename,'wb'))
loaded_model = pickle.load(open('random_regression.sav','rb'))

# %%
user_age = float(input("Enter Age: "))
user_bmi = float(input("Enter BMI: "))
user_children = float(input("Enter Number of Children: "))
user_sex = float(
    input("Enter Sex (1 for Male, 0 for Female): ")
)  # Male = 1, Female = 0
user_smoker = float(
    input("Enter Smoker (1 for Yes, 0 for No): ")
)  # Yes = 1, No = 0
result = loaded_model.predict([[user_age,user_sex,user_bmi,user_children,user_smoker]])
result
# input_data = pd.DataFrame(
#     [[user_age, user_bmi, user_children, user_sex, user_smoker]],
#     columns=['age', 'bmi', 'children', 'sex_male', 'smoker_yes'],
# )

# 4. Predict செய்து முடிவைக் காட்டுதல்
# prediction = loaded_model.predict(input_data)
# prediction
# Out:
# Enter Age:  60
# Enter BMI:  30.78
# Enter Number of Children:  5
# Enter Sex (1 for Male, 0 for Female):  0
# Enter Smoker (1 for Yes, 0 for No):  0
# array([21622.7456794])
