# %%
# pandas libary
import pandas as pd  
# pandas irundhu function get the file
dataset = pd.read_csv('Salary_Data.csv')
# get the variable data file into table list
print(dataset)
# Out:
#    Year  Salary
# 0     1     100
# 1     2     200
# 2     3     300
# 3     4     400
# 4     5     500
# 5     6     600

# %%
# weight checking
weight = regressor.coef_
weight
# Out:
# array([[100.]])

# %%
# bias checking 
bias = regressor.intercept_
bias
# Out:
# array([0.])

# %%
#predict value of x test output
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([[600.],
#        [300.]])

# %%
# metric oda formula and predict the value
from sklearn.metrics import r2_score
r_score = r2_score(y_test,y_pred)
r_score
# Out:
# 1.0

# %%
# use the pickle and save on file in folder .file write and read bias
import pickle
filename ="final_model_linear.sav"

# %%
#  decoder in file 
pickle.dump(regressor,open(filename,'wb'))

# %%
# loaded model  and get input value and output result
loaded_model = pickle.load(open('final_model_linear.sav','rb'))
result = loaded_model.predict([[68]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6800.]])
