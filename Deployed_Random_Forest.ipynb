# %%
import pickle
loaded_model = pickle.load(open('final_model_random_forest.sav','rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pickle
# ----> 2 loaded_model = pickle.load(open('final_model_random_forest.sav','rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final_model_random_forest.sav'
