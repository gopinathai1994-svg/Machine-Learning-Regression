# %%
import pandas as pd
dataset = pd.read_csv('50_Startups.csv')
dataset
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)
independent = dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York' ]]
dependent = dataset[['Profit']]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size =0.3,random_state =0)

# %%
# standarised method
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

scy = StandardScaler()
y_train = scy.fit_transform(y_train)
y_test = scy.transform(y_test)

# %%
reg_input = sc.transform([[2000,3000,1000,1,0]])
reg_input
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.45320659, -4.68772505, -1.53042948,  2.        , -0.76870611]])

# %%
import pickle
import os
# Check where Python is currently looking
print("Current Working Directory:", os.getcwd())

# Check if the file exists in this directory
print(
    "File exists?", os.path.path.exists("input_output_inverser_transform.sav")
)
module_load=pickle.load(open('input_output_inverser_transform.sav','rb'))
result = module_load.predict(reg_input)
result
result_output=scy.inverse_transform([result])
result_output
# Out:
# Current Working Directory: E:\HopeAI_Learning\python_learning\Python_New\Machine_Learning\Machine-Learning-Regression
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       4 print("Current Working Directory:", os.getcwd())
#       5
#       6 # Check if the file exists in this directory
#       7 print(
# ----> 8     "File exists?", os.path.path.exists("input_output_inverser_transform.sav")
#       9 )
#      10 module_load=pickle.load(open('input_output_inverser_transform.sav','rb'))
#      11 result = module_load.predict(reg_input)
#
# AttributeError: module 'ntpath' has no attribute 'path'
