# %%
A) How will you achieve this in AI?
employee in experience, salary, dependency, and Manager level, we can predict whether the employee is interested in the job or not

# %%
B) Find out the 3-Stage of Problem Identification

Stage 1 – Machine Learning
Stage 2 – Supervised Learning
Stage 3 – Classification - (Interested or Not Interested)

# %%
C) Name of the Project

Employee Satisfaction Prediction

# %%
D) Dummy Dataset
EmployeeID,Experience,Salary,Overtime,JobSatisfaction,Promotion,result
102       ,3         , 40000,yes     , 2             ,  No      , Not Interested
103       ,5         , 50000, NO     , 4             , Yes      , Interest
104       ,8         , 60000, NO     , 5             , Yes      , Interest
